# %% [markdown]
# <a href="https://colab.research.google.com/github/Talha2557/Banking-Subscription-Prediction-ML/blob/main/Banking_Subscription_Prediction_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
